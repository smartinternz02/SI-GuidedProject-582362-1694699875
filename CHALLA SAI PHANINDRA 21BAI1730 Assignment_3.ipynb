# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Download the dataset
# ### 2. Load the dataset into the tool.

# %%
df=pd.read_csv('/content/penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ### 3. Perform Below Visualizations.
# univariate analysis

# %%
df.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
sns.distplot(df.body_mass_g	)
# Out:
# <ipython-input-69-94deb719b3cc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.body_mass_g	)
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.displot(df.	species)

# %%
plt.pie(df['island'].value_counts(),[0,0,0.1],labels=['Biscoe ','Dream ','Torgersen'],autopct='%1.1f%%',shadow=True,colors=['red','skyblue','yellow'])
plt.title('island')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Bivariate analysis

# %% [markdown]
# flipper_length_mm vs	body_mass_g

# %%
sns.lineplot(x=df['flipper_length_mm'],y=df['body_mass_g'])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(x=df['flipper_length_mm'],y=df['body_mass_g'])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.jointplot(x='flipper_length_mm' ,y='body_mass_g',data=df)

# %% [markdown]
# Multivariate Analysis

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-76-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ### 4. Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ### 5. Check for Missing values and deal with them

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
df.sex=df.sex.replace('.','MALE')

# %%
df.sex.value_counts()
# Out:
# MALE      169
# FEMALE    165
# Name: sex, dtype: int64

# %% [markdown]
# mode is male so we will replace null values with male

# %%
df.sex=df.sex.fillna('MALE')

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     2
# culmen_depth_mm      2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# dtype: int64

# %%
df.median()
# Out:
# <ipython-input-88-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# culmen_length_mm       44.45
# culmen_depth_mm        17.30
# flipper_length_mm     197.00
# body_mass_g          4050.00
# dtype: float64

# %%
df=df.fillna(df.median())
# Out:
# <ipython-input-89-42d29455c84b>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.median())

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen             39.10             18.7              181.0
# 1    Adelie  Torgersen             39.50             17.4              186.0
# 2    Adelie  Torgersen             40.30             18.0              195.0
# 3    Adelie  Torgersen             44.45             17.3              197.0
# 4    Adelie  Torgersen             36.70             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe             44.45             17.3              197.0
# 340  Gentoo     Biscoe             46.80             14.3              215.0
# 341  Gentoo     Biscoe             50.40             15.7              222.0
# 342  Gentoo     Biscoe             45.20             14.8              212.0
# 343  Gentoo     Biscoe             49.90             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# ### 6. Find the outliers and replace them outliers

# %% [markdown]
# ## outlier detection

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0    MALE
# 4       3450.0  FEMALE

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.	body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# Outliers are not Detected so there is no Outliers so no need to replace the outliers

# %% [markdown]
# ### 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['species'] = le.fit_transform(df['species'])
df['island'] = le.fit_transform(df['island'])
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 3       4050.0    1
# 4       3450.0    0

# %% [markdown]
# ### 8.Check the correlation of independent variables with the target(target is species)

# %%
df.corr().species.sort_values(ascending=False)
# Out:
# species              1.000000
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# culmen_length_mm     0.728706
# sex                  0.010240
# island              -0.635659
# culmen_depth_mm     -0.741282
# Name: species, dtype: float64

# %% [markdown]
# ### 9. Split the data into dependent and independent variables.

# %%
X=df.drop(columns=['species'],axis=1)
X.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0

# %%
Y=df['species']
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %% [markdown]
# ### 10. Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
X_scaled = pd.DataFrame(scale.fit_transform(X),columns=X.columns)
X_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  0.0

# %% [markdown]
# ### 11. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_scaled,Y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 49      0.5          0.370909         0.964286           0.322034
# 310     0.0          0.560000         0.226190           0.779661
# 325     0.0          0.534545         0.357143           0.728814
# 122     1.0          0.294545         0.464286           0.067797
# 167     0.5          0.669091         0.773810           0.491525
#
#      body_mass_g  sex
# 49      0.402778  1.0
# 310     0.625000  0.0
# 325     0.777778  1.0
# 122     0.208333  0.0
# 167     0.375000  1.0

# %%
X_test.head()
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 141     0.5          0.309091         0.488095           0.254237
# 6       1.0          0.247273         0.559524           0.152542
# 60      0.0          0.130909         0.452381           0.220339
# 249     0.0          0.650909         0.261905           0.813559
# 54      0.0          0.087273         0.595238           0.254237
#
#      body_mass_g  sex
# 141     0.215278  1.0
# 6       0.256944  0.0
# 60      0.125000  0.0
# 249     0.791667  1.0
# 54      0.055556  0.0

# %%
Y_train.head()
# Out:
# 49     0
# 310    2
# 325    2
# 122    0
# 167    1
# Name: species, dtype: int64

# %%
Y_test.head()
# Out:
# 141    0
# 6      0
# 60     0
# 249    2
# 54     0
# Name: species, dtype: int64

# %% [markdown]
# ### 12.check the training and testing data shape

# %%
X_train.shape
# Out:
# (275, 6)

# %%
X_test.shape
# Out:
# (69, 6)

# %%
Y_train.shape
# Out:
# (275,)

# %%
Y_test.shape
# Out:
# (69,)

# %% [markdown]
# ## ******THE END******
